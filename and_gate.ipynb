# %% [markdown]
# # AND Gate Using CNN

# %% [markdown]
# ## Import packages

# %%
import numpy as np
from keras.layers import Dense
from keras.models import Sequential

# %% [markdown]
# ## Initializing train and test data

# %%
train_data = np.array([[0, 0], [0, 1],
                        [1, 0], [1, 1]])
target_data = np.array([[0], [0], 
                        [0], [1]])

# %% [markdown]
# ## Keras Models
# ### Adding sequential models

# %%
model = Sequential()
model.add(Dense(32, input_dim=2, 
                activation='relu'))
model.add(Dense(1, 
                activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                96
#
#  dense_1 (Dense)             (None, 1)                 33
#
# ...
# Total params: 129
# Trainable params: 129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
epoch = 500
history = model.fit(train_data, target_data, epochs=epoch, callbacks=None)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.2510 - accuracy: 0.7500
# Epoch 2/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2502 - accuracy: 0.7500
# Epoch 3/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2492 - accuracy: 0.7500
# Epoch 4/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2483 - accuracy: 0.7500
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2473 - accuracy: 0.7500
# Epoch 6/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2464 - accuracy: 0.7500
# Epoch 7/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2455 - accuracy: 0.7500
# Epoch 8/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2446 - accuracy: 0.7500
# Epoch 9/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2438 - accuracy: 0.7500
# Epoch 10/500
# ...

# %% [markdown]
# ## Evaluation

# %%
scores = model.evaluate(train_data, target_data)
# Out:
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0099 - accuracy: 1.0000

# %% [markdown]
# ## Plotting model

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 4))
plt.plot(range(epoch), history.history['accuracy'], label="Accuracy")
plt.plot(range(epoch), history.history['loss'], label="Loss")
plt.legend(loc="right")
plt.show()

# %% [markdown]
# ## Predict Model

# %%
model.predict(np.array([[1, 1]])).round()
# Out:
# 1/1 [==============================] - 0s 154ms/step
# array([[1.]], dtype=float32)
